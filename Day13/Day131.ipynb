# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Example 1:
dataset = pd.read_csv('df_vacation.csv',parse_dates=['Month'],index_col=0)
dataset.head()
# Out:
#             Num_Search_Vacation
# Month
# 2004-01-01                   94
# 2004-02-01                   89
# 2004-03-01                   86
# 2004-04-01                   79
# 2004-05-01                   89

# %%
#Plot the time series graph
dataset.plot(color='blue',grid=True, figsize=(8,6))
# Out:
# <Axes: xlabel='Month'>

# %%
#Example 2:
dataset = pd.read_csv('df_furniture.csv',parse_dates=['Month'],index_col=0)
dataset.head()
# Out:
#             furniture_price_adjusted
# Month
# 1992-01-01               2073.432724
# 1992-02-01               2114.485812
# 1992-03-01               2260.570891
# 1992-04-01               2255.103236
# 1992-05-01               2331.414618

# %%
#Plot the time series graph
dataset.plot(color='blue',grid=True, figsize=(8,6))
# Out:
# <Axes: xlabel='Month'>

# %%
#Example 3:
dataset = pd.read_csv('df_jpmorgan.csv',parse_dates=['Date'],index_col=0)
dataset.head()
# Out:
#             Adj Close Price
# Date
# 1990-01-02         3.610043
# 1990-01-03         3.730377
# 1990-01-04         3.745418
# 1990-01-05         3.760463
# 1990-01-08         3.760463

# %%
#Plot the time series graph
dataset.plot(color='blue',grid=True, figsize=(8,6))
# Out:
# <Axes: xlabel='Date'>
